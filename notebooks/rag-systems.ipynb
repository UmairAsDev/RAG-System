# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("nvidia/NV-Embed-v1", use_auth_token="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", trust_remote_code=True)
# Out:
# No sentence-transformers model found with name nvidia/NV-Embed-v1. Creating a new one with mean pooling.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\portfolio projects\Rag-System-Project\env\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File d:\portfolio projects\Rag-System-Project\env\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/nvidia/NV-Embed-v1/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# ...
